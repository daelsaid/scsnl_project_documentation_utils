# %% [markdown]
# ### Load packages
# ##### DE 20190708 v.1

# %%
import os
import pandas as pd
import sys

# %% [markdown]
# ### set path to folder that will be created through bash commands below

# %%
all_assess_dirs='/Users/daelsaid/scratch/Neuropsych_organized/all-subj-box/fresh_download_20190708/all_assessments'

# %% [markdown]
# #### 1. Make a copy of MET subjects PID folders in the SCSNL behavioral data folders
# #### 2. Download copy to your computer (local scratch space) using rclone (needs to be configured)
#
# *make sure to adjust your paths to the appropriate locations on your personal computer
# *make sure to remove the # sign to actually execute any copies/renaming/changing of files, they are commented out to prevent accidents

# %%
# %%bash
# cd ~/scratch/Neuropsych_organized/all-subj-box/fresh_download_20190708
# for subj in `ls -d 9*[0-9]*`; do
#     echo $subj;
#     cd ~/scratch/Neuropsych_organized/all-subj-box/fresh_download_20190708;
# #     rclone copy stanford_box:/daelsaid_externally_shared_files/ ~/scratch/Neuropsych_organized/all-subj-box/fresh_download_20190708/;
# done
# Out:
# 9002
# 9021
# 9032
# 9033
# 9038
# 9040
# 9054
# 9071
# 9120
# 9145
# 9174
# 9177
# 9212
# 9218
# 9226
# 9297
# 9337
# 9347
# 9354
# 9370
# 9430
# 9440
# 9476
# 9496
# 9839

# %% [markdown]
# #### 3. Create a new folder "all_asssessments"

# %%
# %%bash
#
# # mkdir all_assessments;

# %% [markdown]
# #### 4. Find all the excel files within each participants folder and copy a them into the all_assessments folder

# %%
# %%bash
#
# cd ~/scratch/Neuropsych_organized/all-subj-box/fresh_download_20190708;
#
# for files in in `find 9*/ -name '*.xlsx*' -type f | grep -v template.xlsx`; do
#     echo $files;
# #     cp $files all_assessments/;
# done
# Out:
# in
# 9002//visit1/standardized_experiments/MET_WJ_III_9002_1.xlsx
# 9002//visit1/standardized_experiments/MET_DKEFS_9002_1.xlsx
# 9002//visit1/standardized_experiments/MET_WIAT_III_9002_1.xlsx
# 9002//visit1/standardized_experiments/MET_WISC_V_9002_1.xlsx
# 9002//visit1/standardized_experiments/MET_WASI_II_9002_1.xlsx
# 9002//visit1/lab_experiments/tutoring/MET_VNT_Tutoring_9002_1.xlsx
# 9002//visit1/lab_experiments/questionnaires/CBO_scoring_for_MET_9002.xlsx
# 9002//visit1/lab_experiments/questionnaires/MET_Handedness_scoring_9002.xlsx
# 9002//visit1/lab_experiments/questionnaires/MET_ATM_9002_1.xlsx
# 9002//visit1/lab_experiments/questionnaires/MET_MARS(SEMA)_9002_1.xlsx
# 9002//visit1/lab_experiments/questionnaires/MET_ATL_9002_1.xlsx
# 9002//visit1/lab_experiments/strategy_assessment/MET_Pre_Strategy_Assessment_9002_1.xlsx
# 9002//visit1/lab_experiments/strategy_assessment/FINAL_IMPORT_MET_Strategy_Assessment_9002_1.xlsx
# 9002//visit1/lab_experiments/MET_Geary's_9002.xlsx
# 9002//visit1/lab_experiments/MET_Learning_Curve_9002_1.xlsx
# 9002//visit1/lab_experiments/MET_Subtraction_9002_1.xlsx
# 9002//visit2/standardized_experiments/MET_WJ_III_9002_2.xlsx
# 9002//visit2/lab_experiments/MET_Geary's_9002_2.xlsx
# 9120//visit2/assessments/lab_experiments/strategy_assessment/MET_Post_Strategy_Assessment_9120_2.xlsx
# 9120//visit2/assessments/lab_experiments/MET_Geary's_9120_2.xlsx
# 9145//visit1/assessments/standardized_experiments/MET_WJ_III_9145_1.xlsx
# 9145//visit1/assessments/standardized_experiments/MET_WIAT_III_template_9145_1.xlsx
# 9145//visit1/assessments/standardized_experiments/MET_WASI_II_template_9145_1.xlsx
# 9145//visit1/assessments/lab_experiments/tutoring/MET_SPT_Tutoring_9145_1.xlsx
# 9145//visit1/assessments/lab_experiments/tutoring/MET_SPT_CBO_9145_1.xlsx
# 9145//visit1/assessments/lab_experiments/strategy_assessment/MET_Pre_Strategy_Assessment_9145_1.xlsx
# 9145//visit1/assessments/lab_experiments/MET_Handedness_scoring_9145_1.xlsx
# 9145//visit1/assessments/lab_experiments/MET_Learning_Curve_9145_1.xlsx
# 9145//visit1/assessments/lab_experiments/MET_Subtraction_9145_1.xlsx
# 9145//visit1/assessments/lab_experiments/CBO_scoring_for_MET_9145.xlsx
# 9145//visit2/assessments/lab_experiments/questionnaire/MET_ATL_9145_2.xlsx
# 9145//visit2/assessments/lab_experiments/questionnaire/MET_MARS(SEMA)_9145_2.xlsx
# 9145//visit2/assessments/lab_experiments/questionnaire/MET_ATM_9145_2.xlsx
# 9174//visit1/standardized_experiments/Baseline
# Measure
# Scoring_9174_1.xlsx
# 9174//visit1/standardized_experiments/Group
# A
# SPT
# Problem
# Trackers_9174.xlsx
# 9174//visit1/standardized_experiments/Woodcock
# Johnson_scoring_for_DB_All_Grades_FINAL_Feb2017_9174_1.xlsx
# 9174//visit1/standardized_experiments/WASI_scoring_for_DB_All_Grades_19Nov15_9174_1.xlsx
# 9174//visit1/standardized_experiments/Woodcock
# Johnson_9174_A.xlsx
# 9177//visit1/standardized_experiments/WIATIII_scoring_for_DB_9177_1.xlsx
# 9212//visit1/assessments/standardized_experiments/MET_WASI_II_9212_1.xlsx
# 9212//visit1/assessments/standardized_experiments/MET_WIAT_III_9212_1.xlsx
# 9212//visit1/assessments/lab_experiments/questionnaires/MET_Handedness_9212_1.xlsx
# 9218//visit1/standardized_experiments/WIATIII_scoring_for_DB_9218.xlsx
# 9218//visit1/standardized_experiments/WASI_II_scoring_for_DB_9218_1.xlsx
# 9218//visit1/standardized_experiments/Group
# A
# Problem
# Trackers_Master_VNT_9218.xlsx
# 9218//visit1/standardized_experiments/Learning
# Curve_A_Scoring_9128.xlsx
# 9218//visit1/standardized_experiments/Baseline
# Scoring_Master_NEW_A_9218.xlsx
# 9218//visit1/standardized_experiments/Woodcock
# Johnson_scoring_for_DB_9218_A.xlsx
# 9226//visit1/standardized_experiments/Woodcock_Johnson_9226_FormB.xlsx
# 9226//visit1/standardized_experiments/WASI_scoring_for_DB_9226.xlsx
# 9226//visit1/standardized_experiments/Group
# A
# SPT
# Problem
# Trackers_9226.xlsx
# 9226//visit1/standardized_experiments/Woodcock
# Johnson_scoring_9226_FormA.xlsx
# 9226//visit1/standardized_experiments/Baseline
# Measure
# 9496//visit1/assessments/lab_experiments/questionnares/CBO_scoring_for_MET_9496.xlsx
# 9496//visit2/assessments/standardized_experiments/MET_WJ_III_9496_2.xlsx
# 9496//visit2/assessments/lab_experiments/strategy_assessment/MET_Post_Strategy_Assessment_9496_2.xlsx
# 9496//visit2/assessments/lab_experiments/questionnaire/MET_ATM_9496_2.xlsx
# 9496//visit2/assessments/lab_experiments/questionnaire/MET_MARS(SEMA)_9496_2.xlsx
# 9496//visit2/assessments/lab_experiments/questionnaire/MET_ATL_9496_2.xlsx
# 9496//visit2/assessments/lab_experiments/MET_Geary's_9496_2.xlsx
# 9496//visit2/assessments/lab_experiments/MET_Subtraction_9496_2.xlsx
# 9839//visit1/standardized_experiments/Group
# A
# Problem
# Trackers_Master_VNT_9839.xlsx
# 9839//visit1/standardized_experiments/Baseline
# Measure
# Scoring_9839.xlsx
# 9839//visit1/standardized_experiments/Woodcock
# Johnson_scoring_for_DB_9839_A.xlsx
# 9839//visit1/standardized_experiments/Woodcock
# Johnson_scoring_for_DB_9839_B.xlsx
# 9839//visit1/standardized_experiments/WASI_II_scoring_for_DB_9839_1.xlsx

# %% [markdown]
# #### 5. Find all unique listings of file names and rename files

# %%
# %%bash
#
# cd ~/scratch/Neuropsych_organized/all-subj-box/fresh_download_20190708/all_assessments;
# # rename 's/WISC_V_MET/MET_WISC_V/g' WISC_V_MET*.xlsx` (commandline)

# %%
def install(name):
    import subprocess
    subprocess.call(['pip', 'install', name])

# %% [markdown]
# #### 6. Set 4 empty lists (these will be populated as each subject's template is checked)
# #### 7. For each PID's template, check the import_formula tab for 4 different key strings that reflect scoring status
# - 'Assessor to complete'
# - 'Scorer1 to complete'
# - 'Scorer2 to complete'
# - 'check'
# #### 8. If each key string is not found in the import formula tab, print 'assessor/score1/score2 complete/no checks needed for PID, visit #, assessment name'
# #### 9. If key string is found in the import formula tab, append the PID,visit#, assessment name into respective lists (needs_assessor,needs_score1,needs_score2,needs_check)

# %%
needs_assessor=[]
needs_score1=[]
needs_score2=[]
needs_check=[]

os.chdir(all_assess_dirs)

for subj_data_file in os.listdir(all_assess_dirs):
    file_prefix=subj_data_file.split('.')[0]
    try:
        subject=file_prefix.split('_')[-2]
        visit=file_prefix.split('_')[-1]
        assessment=file_prefix.split('_9')[0].split('MET_')[1]
        subj_df=pd.read_excel(subj_data_file,sheetname='Import_Formula',header=[0],skiprows=None,dtype=str)

        if (subj_df.values=='Assessor to complete').any() == True:
            needs_assessor.append([subject,visit,assessment])
        else:
            print subject,visit,assessment,': Assessor scoring complete'
        if (subj_df.values=='Scorer1 to complete').any() == True:
            needs_score1.append([subject,visit,assessment])
        else:
            print subject,visit,assessment,': Score1 scoring complete'
        if (subj_df.values=='Scorer2 to complete').any() == True:
            needs_score2.append([subject,visit,assessment])
        else:
            print subject,visit,assessment,': Scorer2 scoring complete'
        if (subj_df.values=='check').any() == True:
            needs_check.append([subject,visit,assessment])
    except:
        print ""
        print('error in cell values for:',file_prefix,'file cannot be read')
        continue
# Out:
# 9370 1 WJ_III : Assessor scoring complete
# 9370 1 WJ_III : Score1 scoring complete
# 9370 1 WJ_III : Scorer2 scoring complete
# 9496 2 ATM : Assessor scoring complete
# 9496 2 ATM : Score1 scoring complete
# 9496 2 ATM : Scorer2 scoring complete
# 9337 2 ATL : Assessor scoring complete
# 9337 2 ATL : Scorer2 scoring complete
# 9033 1 WISC_V : Assessor scoring complete
# 9033 1 WISC_V : Score1 scoring complete
# 9033 1 WISC_V : Scorer2 scoring complete
# 9476 2 Geary's : Assessor scoring complete
# 9476 2 Geary's : Score1 scoring complete
# 9476 2 Geary's : Scorer2 scoring complete
# 9337 1 WJ_III : Assessor scoring complete
# 9337 1 WJ_III : Score1 scoring complete
# 9337 1 WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Handedness_9120_1', 'file cannot be read')
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9120_2', 'file cannot be read')
# 9032 1 ATM : Assessor scoring complete
# 9032 1 ATM : Score1 scoring complete
# 9032 1 ATM : Scorer2 scoring complete
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9297_2', 'file cannot be read')
# 9440 2 Geary's : Assessor scoring complete
# 9440 2 Geary's : Score1 scoring complete
# 9440 2 Geary's : Scorer2 scoring complete
# Curve 9476 Learning_Curve : Assessor scoring complete
# Curve 9476 Learning_Curve : Score1 scoring complete
# Curve 9476 Learning_Curve : Scorer2 scoring complete
# 9297 1 ATM : Assessor scoring complete
# 9297 1 ATM : Score1 scoring complete
# 9297 1 ATM : Scorer2 scoring complete
# 9120 1 ATM : Assessor scoring complete
# 9120 1 ATM : Score1 scoring complete
# 9120 1 ATM : Scorer2 scoring complete
# 9347 2 MARS(SEMA) : Assessor scoring complete
# 9347 2 MARS(SEMA) : Score1 scoring complete
# 9347 2 MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'strategy_assess_9033_Time_2_X_10_29_42_Ver', 'file cannot be read')
# 9430 1 Subtraction : Assessor scoring complete
# 9430 1 Subtraction : Score1 scoring complete
# 9430 1 Subtraction : Scorer2 scoring complete
#
# ('error in cell values for:', 'Woodcock_Johnson_9226_FormB', 'file cannot be read')
# 9476 post MARS(SEMA) : Assessor scoring complete
# 9476 post MARS(SEMA) : Score1 scoring complete
# 9476 post MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9476_1', 'file cannot be read')
# 9145 1 WJ_III : Assessor scoring complete
# 9145 1 WJ_III : Score1 scoring complete
# 9145 1 WJ_III : Scorer2 scoring complete
# 9496 1 Subtraction : Assessor scoring complete
# 9496 1 Subtraction : Score1 scoring complete
# 9496 1 Subtraction : Scorer2 scoring complete
# 9002 2 ATL : Assessor scoring complete
# 9002 2 ATL : Score1 scoring complete
# 9002 2 ATL : Scorer2 scoring complete
# 9040 2 WJ_III : Assessor scoring complete
# 9040 2 WJ_III : Score1 scoring complete
# 9040 2 WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'WASI_scoring_for_DB_9226', 'file cannot be read')
# 9002 1 WJ_III : Assessor scoring complete
# 9002 1 WJ_III : Score1 scoring complete
# 9002 1 WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9430_1', 'file cannot be read')
# 9033 1 Geary's : Assessor scoring complete
# 9033 1 Geary's : Score1 scoring complete
# 9033 1 Geary's : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_ATL_9040_1', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9347_2', 'file cannot be read')
#
# ('error in cell values for:', 'WASI_II_scoring_for_DB_9218_1', 'file cannot be read')
# 9347 1 VNT_CBO : Scorer2 scoring complete
# 9033 3 WJ_III : Assessor scoring complete
# 9033 3 WJ_III : Score1 scoring complete
# 9033 3 WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'Subtraction_MET_9054_1', 'file cannot be read')
# 9430 2 ATM : Assessor scoring complete
# 9430 2 ATM : Score1 scoring complete
# 9430 2 ATM : Scorer2 scoring complete
# 9120 2 Subtraction : Assessor scoring complete
# 9120 2 Subtraction : Score1 scoring complete
# 9120 2 Subtraction : Scorer2 scoring complete
# 9297 2 Subtraction : Assessor scoring complete
# 9297 2 Subtraction : Score1 scoring complete
# 9297 2 Subtraction : Scorer2 scoring complete
# 9347 3 ATM : Assessor scoring complete
# 9347 3 ATM : Score1 scoring complete
# 9347 3 ATM : Scorer2 scoring complete
# 9145 2 ATL : Assessor scoring complete
# 9145 2 ATL : Score1 scoring complete
# 9145 2 ATL : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9476', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9337_1', 'file cannot be read')
#
# ('error in cell values for:', 'MET_CBO_scoring_9347_3', 'file cannot be read')
# 9347 2 ATM : Assessor scoring complete
# 9347 2 ATM : Score1 scoring complete
# 9347 2 ATM : Scorer2 scoring complete
# 9120 1 MARS(SEMA) : Assessor scoring complete
# 9120 1 MARS(SEMA) : Score1 scoring complete
# 9120 1 MARS(SEMA) : Scorer2 scoring complete
# 9297 1 MARS(SEMA) : Assessor scoring complete
# 9297 1 MARS(SEMA) : Score1 scoring complete
# 9297 1 MARS(SEMA) : Scorer2 scoring complete
# 9297 3 Subtraction : Assessor scoring complete
# 9297 3 Subtraction : Score1 scoring complete
# 9297 3 Subtraction : Scorer2 scoring complete
# 9033 2 WJ_III : Assessor scoring complete
# 9033 2 WJ_III : Score1 scoring complete
# 9033 2 WJ_III : Scorer2 scoring complete
# 9054 1 LearningCurve : Assessor scoring complete
# 9054 1 LearningCurve : Score1 scoring complete
#
# ('error in cell values for:', 'WIAT_III_scoring_for_DB_9177_1', 'file cannot be read')
#
# ('error in cell values for:', 'strategy_assess_9347_Time_2_X_14_58_30_Ver', 'file cannot be read')
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9347_1', 'file cannot be read')
# 9040 1 SPT_CBO : Assessor scoring complete
# 9040 1 SPT_CBO : Score1 scoring complete
# 9040 1 SPT_CBO : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9430_2', 'file cannot be read')
# 9120 1 WJ_III_verA : Assessor scoring complete
# 9120 1 WJ_III_verA : Score1 scoring complete
# 9120 1 WJ_III_verA : Scorer2 scoring complete
# 9040 1 Geary's : Assessor scoring complete
# 9040 1 Geary's : Score1 scoring complete
# 9040 1 Geary's : Scorer2 scoring complete
# 9033 1 ATL : Assessor scoring complete
# 9033 1 ATL : Score1 scoring complete
# 9033 1 ATL : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9370_1', 'file cannot be read')
# 9496 2 MARS(SEMA) : Assessor scoring complete
# 9496 2 MARS(SEMA) : Score1 scoring complete
# 9496 2 MARS(SEMA) : Scorer2 scoring complete
# 9120 1 WIAT_III : Assessor scoring complete
# 9120 1 WIAT_III : Score1 scoring complete
# 9120 1 WIAT_III : Scorer2 scoring complete
# 9297 1 WIAT_III : Assessor scoring complete
# 9297 1 WIAT_III : Score1 scoring complete
# 9297 1 WIAT_III : Scorer2 scoring complete
# 9496 1 Learning_Curve : Assessor scoring complete
# 9496 1 Learning_Curve : Score1 scoring complete
# 9496 1 Learning_Curve : Scorer2 scoring complete
# 9032 1 WIAT_III : Assessor scoring complete
# 9032 1 WIAT_III : Score1 scoring complete
# 9032 1 WIAT_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9002_1', 'file cannot be read')
#
# ('error in cell values for:', 'strategy_assess_9033_Time_4_Z_10_13_12_Ver', 'file cannot be read')
#
# ('error in cell values for:', 'strategy_assess_9347_Time_1_W_12_55_13_Ver', 'file cannot be read')
# 9347 3 MARS(SEMA) : Assessor scoring complete
# 9347 3 MARS(SEMA) : Score1 scoring complete
# 9347 3 MARS(SEMA) : Scorer2 scoring complete
# 9040 1 WASI_II : Assessor scoring complete
# 9040 1 WASI_II : Score1 scoring complete
# 9040 1 WASI_II : Scorer2 scoring complete
# 9347 1 Subtraction : Assessor scoring complete
# 9347 1 Subtraction : Score1 scoring complete
# 9347 1 Subtraction : Scorer2 scoring complete
# 9430 2 MARS(SEMA) : Assessor scoring complete
# 9430 2 MARS(SEMA) : Score1 scoring complete
# 9430 2 MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_DKEFS_9120_1', 'file cannot be read')
# 9297 1 DKEFS : Assessor scoring complete
# 9297 1 DKEFS : Score1 scoring complete
# 9297 1 DKEFS : Scorer2 scoring complete
# 9337 2 Geary's : Assessor scoring complete
# 9430 1 Learning_Curve : Assessor scoring complete
# 9430 1 Learning_Curve : Score1 scoring complete
# 9430 1 Learning_Curve : Scorer2 scoring complete
# 9054 B WJ_III : Assessor scoring complete
# 9054 B WJ_III : Score1 scoring complete
# 9054 B WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_CBO_scoring_9032_1', 'file cannot be read')
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9297_3', 'file cannot be read')
# 9040 1 WISC_V : Assessor scoring complete
# 9040 1 WISC_V : Score1 scoring complete
# 9040 1 WISC_V : Scorer2 scoring complete
#
# ('error in cell values for:', 'MARS(SEMA)_MET_9032_1', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9145_1', 'file cannot be read')
# 9476 1 WJ_III : Assessor scoring complete
# 9476 1 WJ_III : Score1 scoring complete
# 9476 1 WJ_III : Scorer2 scoring complete
# 9120 1 SPT_Tutoring : Assessor scoring complete
# 9120 1 SPT_Tutoring : Score1 scoring complete
# 9120 1 SPT_Tutoring : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9054', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9496_2', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Handedness_9370_1', 'file cannot be read')
# 9040 1 Subtraction : Assessor scoring complete
# 9040 1 Subtraction : Score1 scoring complete
# 9040 1 Subtraction : Scorer2 scoring complete
# 9347 1 WASI_II : Assessor scoring complete
# 9347 1 WASI_II : Score1 scoring complete
# 9347 1 WASI_II : Scorer2 scoring complete
# 9496 2 WJ_III : Assessor scoring complete
# 9496 2 WJ_III : Score1 scoring complete
# 9496 2 WJ_III : Scorer2 scoring complete
# 9370 1 ATM : Assessor scoring complete
# 9370 1 ATM : Score1 scoring complete
# 9370 1 ATM : Scorer2 scoring complete
# 9476 1 DKEFS : Score1 scoring complete
# 9476 1 DKEFS : Scorer2 scoring complete
# 9297 2 ATL : Assessor scoring complete
# 9297 2 ATL : Score1 scoring complete
# 9297 2 ATL : Scorer2 scoring complete
# 9120 2 ATL : Assessor scoring complete
# 9120 2 ATL : Score1 scoring complete
# 9120 2 ATL : Scorer2 scoring complete
# 9347 1 WISC_V : Score1 scoring complete
# 9347 1 WISC_V : Scorer2 scoring complete
#
# ('error in cell values for:', 'strategy_assess_9033_Time_3_Y_08_54_56_Ver', 'file cannot be read')
# 9297 3 Geary's : Assessor scoring complete
# 9297 3 Geary's : Score1 scoring complete
# 9297 3 Geary's : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_DKEFS_9440_1', 'file cannot be read')
# 9071 1 WIAT_III : Assessor scoring complete
# 9071 1 WIAT_III : Score1 scoring complete
# 9071 1 WIAT_III : Scorer2 scoring complete
# 9033 1 Learning_Curve : Assessor scoring complete
# 9033 1 Learning_Curve : Score1 scoring complete
# 9033 1 Learning_Curve : Scorer2 scoring complete
#
# ('error in cell values for:', 'test', 'file cannot be read')
# 9297 1 WJ_III : Assessor scoring complete
# 9297 1 WJ_III : Score1 scoring complete
# 9297 1 WJ_III : Scorer2 scoring complete
# 9347 1 VNT_Tutoring : Assessor scoring complete
# 9347 1 VNT_Tutoring : Score1 scoring complete
# 9033 2 MARS(SEMA) : Assessor scoring complete
# 9033 2 MARS(SEMA) : Score1 scoring complete
# 9033 2 MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_CBO_scoring_9145', 'file cannot be read')
# 9212 1 WASI_II : Assessor scoring complete
# 9212 1 WASI_II : Score1 scoring complete
# 9212 1 WASI_II : Scorer2 scoring complete
# 9337 1 ATM : Assessor scoring complete
# 9337 1 ATM : Score1 scoring complete
# 9337 1 ATM : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_CBO_scoring_9440_1', 'file cannot be read')
# 9496 1 ATL : Assessor scoring complete
# 9496 1 ATL : Score1 scoring complete
# 9496 1 ATL : Scorer2 scoring complete
# 9476 1 MARS(SEMA) : Assessor scoring complete
# 9476 1 MARS(SEMA) : Score1 scoring complete
# 9476 1 MARS(SEMA) : Scorer2 scoring complete
# 9040 2 ATM : Assessor scoring complete
# 9040 2 ATM : Score1 scoring complete
# 9040 2 ATM : Scorer2 scoring complete
# 9440 1 WIAT_III : Assessor scoring complete
# 9440 1 WIAT_III : Score1 scoring complete
# 9440 1 WIAT_III : Scorer2 scoring complete
# 9430 1 ATL : Assessor scoring complete
# 9430 1 ATL : Score1 scoring complete
# 9430 1 ATL : Scorer2 scoring complete
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9040_1', 'file cannot be read')
# 9347 1 Geary's : Assessor scoring complete
# 9347 1 Geary's : Score1 scoring complete
# 9347 1 Geary's : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Handedness_scoring_9002', 'file cannot be read')
# 9476 1 WIAT_III : Assessor scoring complete
# 9476 1 WIAT_III : Score1 scoring complete
# 9476 1 WIAT_III : Scorer2 scoring complete
# 9430 2 WJ_III : Assessor scoring complete
# 9430 2 WJ_III : Score1 scoring complete
# 9430 2 WJ_III : Scorer2 scoring complete
# 9347 3 WJ_III : Assessor scoring complete
# 9347 3 WJ_III : Score1 scoring complete
# 9347 3 WJ_III : Scorer2 scoring complete
# 9054 post MARS(SEMA) : Assessor scoring complete
# 9054 post MARS(SEMA) : Score1 scoring complete
# 9054 post MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'strategy_assess_9347_Time_4_Z_10_45_17_Ver', 'file cannot be read')
# 9033 3 ATM : Assessor scoring complete
# 9033 3 ATM : Score1 scoring complete
# 9033 3 ATM : Scorer2 scoring complete
# 9002 1 ATM : Assessor scoring complete
# 9002 1 ATM : Score1 scoring complete
# 9002 1 ATM : Scorer2 scoring complete
# 9440 1 MARS(SEMA) : Assessor scoring complete
# 9440 1 MARS(SEMA) : Score1 scoring complete
# 9440 1 MARS(SEMA) : Scorer2 scoring complete
# 9337 2 Subtraction : Assessor scoring complete
# 9496 1 WISC_V : Assessor scoring complete
# 9496 1 WISC_V : Score1 scoring complete
# 9496 1 WISC_V : Scorer2 scoring complete
# 9440 2 Subtraction : Assessor scoring complete
# 9440 2 Subtraction : Score1 scoring complete
# 9440 2 Subtraction : Scorer2 scoring complete
# 9337 1 MARS(SEMA) : Assessor scoring complete
# 9337 1 MARS(SEMA) : Score1 scoring complete
# 9337 1 MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'strategy_assess_9347_Time_7_Y_11_00_09_Ver', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9120_1', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9297_1', 'file cannot be read')
# 9033 2 ATM : Assessor scoring complete
# 9033 2 ATM : Score1 scoring complete
# 9033 2 ATM : Scorer2 scoring complete
# 9370 1 WIAT_III : Assessor scoring complete
# 9370 1 WIAT_III : Score1 scoring complete
# 9370 1 WIAT_III : Scorer2 scoring complete
# 9496 1 WASI_II : Assessor scoring complete
# 9496 1 WASI_II : Score1 scoring complete
# 9496 1 WASI_II : Scorer2 scoring complete
# 9347 2 WJ_III : Assessor scoring complete
# 9347 2 WJ_III : Score1 scoring complete
# 9347 2 WJ_III : Scorer2 scoring complete
# 9145 1 SPT_Tutoring : Assessor scoring complete
# 9145 1 SPT_Tutoring : Score1 scoring complete
# 9145 1 SPT_Tutoring : Scorer2 scoring complete
# 9054 1 VNT_Tutoring : Assessor scoring complete
# 9054 1 VNT_Tutoring : Score1 scoring complete
# 9054 1 VNT_Tutoring : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Handedness_scoring_9145_1', 'file cannot be read')
# 9430 1 Geary's : Assessor scoring complete
# 9430 1 Geary's : Score1 scoring complete
# 9430 1 Geary's : Scorer2 scoring complete
# 9002 1 DKEFS : Score1 scoring complete
# 9002 1 DKEFS : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9040_2', 'file cannot be read')
# 9054 1 WISC_V : Assessor scoring complete
# 9054 1 WISC_V : Score1 scoring complete
# 9337 1 WIAT_III : Assessor scoring complete
# 9337 1 WIAT_III : Score1 scoring complete
# 9337 1 WIAT_III : Scorer2 scoring complete
# 9347 1 ATL : Assessor scoring complete
# 9347 1 ATL : Score1 scoring complete
# 9347 1 ATL : Scorer2 scoring complete
# 9430 1 SPT_CBO : Assessor scoring complete
# 9430 1 SPT_CBO : Score1 scoring complete
# 9430 1 SPT_CBO : Scorer2 scoring complete
# Geary's 9002 Geary's : Assessor scoring complete
# Geary's 9002 Geary's : Score1 scoring complete
# Geary's 9002 Geary's : Scorer2 scoring complete
# 9370 1 MARS(SEMA) : Assessor scoring complete
# 9370 1 MARS(SEMA) : Score1 scoring complete
# 9370 1 MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_CBO_scoring_9430', 'file cannot be read')
# 9054 1 WASI_II : Assessor scoring complete
# 9054 1 WASI_II : Score1 scoring complete
# 9054 1 WASI_II : Scorer2 scoring complete
# 9476 2 Subtraction : Assessor scoring complete
# 9476 2 Subtraction : Score1 scoring complete
# 9476 2 Subtraction : Scorer2 scoring complete
#
# ('error in cell values for:', 'strategy_assess_9347_Time_5_W_11_04_14_Ver', 'file cannot be read')
# 9440 1 ATM : Assessor scoring complete
# 9440 1 ATM : Score1 scoring complete
# 9440 1 ATM : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_FollowUp_Strategy_Assessment_9033_3', 'file cannot be read')
#
# ('error in cell values for:', 'MET_CBO_scoring_9337_1', 'file cannot be read')
# 9002 1 MARS(SEMA) : Assessor scoring complete
# 9002 1 MARS(SEMA) : Score1 scoring complete
# 9002 1 MARS(SEMA) : Scorer2 scoring complete
# 9033 3 MARS(SEMA) : Assessor scoring complete
# 9033 3 MARS(SEMA) : Score1 scoring complete
# 9033 3 MARS(SEMA) : Scorer2 scoring complete
# 9033 1 Subtraction : Assessor scoring complete
# 9033 1 Subtraction : Score1 scoring complete
# 9033 1 Subtraction : Scorer2 scoring complete
# 9145 1 WIAT_III : Assessor scoring complete
# 9145 1 WIAT_III : Score1 scoring complete
# 9145 1 WIAT_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Handedness_9440_1', 'file cannot be read')
# 9120 2 Geary's : Assessor scoring complete
# 9120 2 Geary's : Score1 scoring complete
# 9120 2 Geary's : Scorer2 scoring complete
# 9297 2 Geary's : Assessor scoring complete
# 9297 2 Geary's : Score1 scoring complete
# 9297 2 Geary's : Scorer2 scoring complete
# 9002 1 WIAT_III : Assessor scoring complete
# 9002 1 WIAT_III : Score1 scoring complete
# 9002 1 WIAT_III : Scorer2 scoring complete
# 9430 1 WISC_V : Assessor scoring complete
# 9430 1 WISC_V : Score1 scoring complete
# 9430 1 WISC_V : Scorer2 scoring complete
# 9297 3 ATL : Assessor scoring complete
# 9297 3 ATL : Score1 scoring complete
# 9297 3 ATL : Scorer2 scoring complete
# 9040 1 Learning_Curve : Assessor scoring complete
# 9040 1 Learning_Curve : Score1 scoring complete
# 9040 1 Learning_Curve : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_DKEFS_9370_1', 'file cannot be read')
# 9040 2 MARS(SEMA) : Assessor scoring complete
# 9040 2 MARS(SEMA) : Score1 scoring complete
# 9040 2 MARS(SEMA) : Scorer2 scoring complete
# 9476 1 ATM : Assessor scoring complete
# 9476 1 ATM : Score1 scoring complete
# 9476 1 ATM : Scorer2 scoring complete
# 9430 1 WASI_II : Assessor scoring complete
# 9430 1 WASI_II : Score1 scoring complete
# 9430 1 WASI_II : Scorer2 scoring complete
# 9337 1 SPT_Tutoring : Assessor scoring complete
# 9496 1 Geary's : Assessor scoring complete
# 9496 1 Geary's : Score1 scoring complete
# 9496 1 Geary's : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_CBO_476_1', 'file cannot be read')
# 9476 post ATM : Assessor scoring complete
# 9476 post ATM : Score1 scoring complete
# 9476 post ATM : Scorer2 scoring complete
# 9002 2 MARS(SEMA) : Assessor scoring complete
# 9002 2 MARS(SEMA) : Score1 scoring complete
# 9002 2 MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_CBO_scoring_9002', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9430_1', 'file cannot be read')
# 9033 2 Subtraction : Assessor scoring complete
# 9033 2 Subtraction : Score1 scoring complete
# 9033 2 Subtraction : Scorer2 scoring complete
# 9297 3 WJ_III : Assessor scoring complete
# 9297 3 WJ_III : Score1 scoring complete
# 9297 3 WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9337_2', 'file cannot be read')
# 9040 1 WIAT_III : Assessor scoring complete
# 9040 1 WIAT_III : Score1 scoring complete
# 9040 1 WIAT_III : Scorer2 scoring complete
# 9002 1 Learning_Curve : Assessor scoring complete
# 9002 1 Learning_Curve : Score1 scoring complete
# 9002 1 Learning_Curve : Scorer2 scoring complete
# 9054 2 Geary's : Assessor scoring complete
# 9054 2 Geary's : Score1 scoring complete
# 9054 2 Geary's : Scorer2 scoring complete
#
# ('error in cell values for:', 'WIAT_III_scoring_for_DB_9021_1', 'file cannot be read')
# 9297 1 Geary's : Assessor scoring complete
# 9297 1 Geary's : Score1 scoring complete
# 9297 1 Geary's : Scorer2 scoring complete
# 9120 1 Geary's : Assessor scoring complete
# 9120 1 Geary's : Score1 scoring complete
# 9120 1 Geary's : Scorer2 scoring complete
# 9297 1 SPT_CBO : Scorer2 scoring complete
# 9120 1 SPT_CBO : Assessor scoring complete
# 9120 1 SPT_CBO : Score1 scoring complete
# 9120 1 SPT_CBO : Scorer2 scoring complete
# 9145 2 MARS(SEMA) : Assessor scoring complete
# 9145 2 MARS(SEMA) : Score1 scoring complete
# 9145 2 MARS(SEMA) : Scorer2 scoring complete
# 9040 1 MARS(SEMA) : Assessor scoring complete
# 9040 1 MARS(SEMA) : Score1 scoring complete
# 9040 1 MARS(SEMA) : Scorer2 scoring complete
# 9145 1 Learning_Curve : Assessor scoring complete
# 9145 1 Learning_Curve : Score1 scoring complete
# 9145 1 Learning_Curve : Scorer2 scoring complete
# 9370 1 VNT_CBO : Scorer2 scoring complete
# 9496 2 Geary's : Assessor scoring complete
# 9496 2 Geary's : Score1 scoring complete
# 9496 2 Geary's : Scorer2 scoring complete
# 9337 2 MARS(SEMA) : Assessor scoring complete
# 9337 2 MARS(SEMA) : Scorer2 scoring complete
# 9033 1 ATM : Assessor scoring complete
# 9033 1 ATM : Score1 scoring complete
# 9033 1 ATM : Scorer2 scoring complete
# 9040 1 SPT_Tutoring : Assessor scoring complete
# 9040 1 SPT_Tutoring : Score1 scoring complete
# 9040 1 SPT_Tutoring : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Handedness_scoring_9040_1', 'file cannot be read')
#
# ('error in cell values for:', 'MET_neuropsych_CBO_370_1', 'file cannot be read')
# 9347 1 WJ_III : Assessor scoring complete
# 9347 1 WJ_III : Score1 scoring complete
# 9347 1 WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9002_2', 'file cannot be read')
# 9337 1 Learning_Curve : Assessor scoring complete
# 9337 1 Learning_Curve : Score1 scoring complete
# 9430 2 Geary's : Assessor scoring complete
# 9430 2 Geary's : Score1 scoring complete
# 9430 2 Geary's : Scorer2 scoring complete
# 9347 3 Geary's : Assessor scoring complete
# 9347 3 Geary's : Score1 scoring complete
# 9347 3 Geary's : Scorer2 scoring complete
# 9297 1 WISC_V : Assessor scoring complete
# 9297 1 WISC_V : Score1 scoring complete
# 9297 1 WISC_V : Scorer2 scoring complete
# 9032 1 WASI_II : Assessor scoring complete
# 9032 1 WASI_II : Score1 scoring complete
# 9032 1 WASI_II : Scorer2 scoring complete
# 9120 1 WISC_V : Assessor scoring complete
# 9120 1 WISC_V : Score1 scoring complete
# 9120 1 WISC_V : Scorer2 scoring complete
# 9347 2 ATL : Assessor scoring complete
# 9347 2 ATL : Score1 scoring complete
# 9347 2 ATL : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9496_1', 'file cannot be read')
#
# ('error in cell values for:', 'MET_CBO_scoring_9040_1', 'file cannot be read')
# 9297 1 WASI_II : Assessor scoring complete
# 9297 1 WASI_II : Score1 scoring complete
# 9297 1 WASI_II : Scorer2 scoring complete
# 9370 1 Learning_Curve : Assessor scoring complete
# 9370 1 Learning_Curve : Score1 scoring complete
# 9120 1 WASI_II : Assessor scoring complete
# 9120 1 WASI_II : Score1 scoring complete
# 9120 1 WASI_II : Scorer2 scoring complete
# 9476 1 Subtraction : Assessor scoring complete
# 9476 1 Subtraction : Score1 scoring complete
# 9476 1 Subtraction : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9054', 'file cannot be read')
#
# ('error in cell values for:', 'WASI_II_9038', 'file cannot be read')
#
# ('error in cell values for:', 'MET_ATM_9040_1', 'file cannot be read')
# 9370 1 Subtraction : Assessor scoring complete
# 9370 1 Subtraction : Score1 scoring complete
# 9370 1 Subtraction : Scorer2 scoring complete
# 9145 2 ATM : Assessor scoring complete
# 9145 2 ATM : Score1 scoring complete
# 9145 2 ATM : Scorer2 scoring complete
# 9347 3 ATL : Assessor scoring complete
# 9347 3 ATL : Score1 scoring complete
# 9347 3 ATL : Scorer2 scoring complete
# 9430 2 ATL : Assessor scoring complete
# 9430 2 ATL : Score1 scoring complete
# 9430 2 ATL : Scorer2 scoring complete
# 9347 2 Geary's : Assessor scoring complete
# 9347 2 Geary's : Score1 scoring complete
# 9347 2 Geary's : Scorer2 scoring complete
# 3 2 Subtraction : Assessor scoring complete
# 3 2 Subtraction : Score1 scoring complete
# 3 2 Subtraction : Scorer2 scoring complete
# 9430 1 WJ_III : Assessor scoring complete
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9002_1', 'file cannot be read')
# 9002 2 ATM : Assessor scoring complete
# 9002 2 ATM : Score1 scoring complete
# 9002 2 ATM : Scorer2 scoring complete
# 9337 1 Subtraction : Assessor scoring complete
# 9337 1 Subtraction : Score1 scoring complete
# 9337 1 Subtraction : Scorer2 scoring complete
# 9496 1 WJ_III : Assessor scoring complete
# 9496 1 WJ_III : Score1 scoring complete
# 9496 1 WJ_III : Scorer2 scoring complete
# 9040 2 Subtraction : Assessor scoring complete
# 9040 2 Subtraction : Score1 scoring complete
# 9040 2 Subtraction : Scorer2 scoring complete
# 9032 1 ATL : Assessor scoring complete
# 9032 1 ATL : Score1 scoring complete
# 9032 1 ATL : Scorer2 scoring complete
# 9145 1 Subtraction : Assessor scoring complete
# 9145 1 Subtraction : Score1 scoring complete
# 9145 1 Subtraction : Scorer2 scoring complete
# 9033 1 WIAT_III : Assessor scoring complete
# 9033 1 WIAT_III : Score1 scoring complete
# 9033 1 WIAT_III : Scorer2 scoring complete
# 9476 B WJ_III : Assessor scoring complete
# 9476 B WJ_III : Score1 scoring complete
# 9476 B WJ_III : Scorer2 scoring complete
# 9120 1 ATL : Assessor scoring complete
# 9120 1 ATL : Score1 scoring complete
# 9120 1 ATL : Scorer2 scoring complete
# 9297 1 ATL : Assessor scoring complete
# 9297 1 ATL : Score1 scoring complete
# 9297 1 ATL : Scorer2 scoring complete
# 9476 post ATL : Assessor scoring complete
# 9476 post ATL : Score1 scoring complete
# 9476 post ATL : Scorer2 scoring complete
# 9054 1 WJ_III : Assessor scoring complete
# 9054 1 WJ_III : Score1 scoring complete
# 9054 1 WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9440_2', 'file cannot be read')
# 9297 2 WJ_III : Assessor scoring complete
# 9297 2 WJ_III : Score1 scoring complete
# 9297 2 WJ_III : Scorer2 scoring complete
# 9120 2 WJ_III : Assessor scoring complete
# 9120 2 WJ_III : Score1 scoring complete
# 9120 2 WJ_III : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9347_1', 'file cannot be read')
# 9033 1 MARS(SEMA) : Assessor scoring complete
# 9033 1 MARS(SEMA) : Score1 scoring complete
# 9033 1 MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'strategy_assess_9033_Time_1_W_08_57_02_Ver', 'file cannot be read')
# 9337 2 ATM : Assessor scoring complete
# 9337 2 ATM : Scorer2 scoring complete
# 9496 2 ATL : Assessor scoring complete
# 9496 2 ATL : Score1 scoring complete
# 9496 2 ATL : Scorer2 scoring complete
# 9002 1 Subtraction : Assessor scoring complete
# 9002 1 Subtraction : Score1 scoring complete
# 9002 1 Subtraction : Scorer2 scoring complete
# Curve 9347 Learning_Curve : Assessor scoring complete
# Curve 9347 Learning_Curve : Score1 scoring complete
# Curve 9347 Learning_Curve : Scorer2 scoring complete
#
# ('error in cell values for:', 'MARS_MET_9347', 'file cannot be read')
# 9297 3 ATM : Assessor scoring complete
# 9297 3 ATM : Score1 scoring complete
# 9297 3 ATM : Scorer2 scoring complete
# 9430 1 MARS(SEMA) : Assessor scoring complete
# 9430 1 MARS(SEMA) : Score1 scoring complete
# 9430 1 MARS(SEMA) : Scorer2 scoring complete
# 9347 2 Subtraction : Assessor scoring complete
# 9347 2 Subtraction : Score1 scoring complete
# 9347 2 Subtraction : Scorer2 scoring complete
# 9496 1 SPT_Tutoring : Assessor scoring complete
# 9496 1 SPT_Tutoring : Score1 scoring complete
# 9496 1 SPT_Tutoring : Scorer2 scoring complete
# 9337 1 Geary's : Assessor scoring complete
# 9337 1 Geary's : Score1 scoring complete
# 9337 1 Geary's : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Handedness_scoring_9496_1', 'file cannot be read')
# 9145 1 WASI_II : Assessor scoring complete
# 9145 1 WASI_II : Score1 scoring complete
# 9145 1 WASI_II : Scorer2 scoring complete
# 9054 1 DKEFS : Assessor scoring complete
# 9054 1 DKEFS : Score1 scoring complete
# 9054 1 DKEFS : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9297_2', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Post_Strategy_Assessment_9120_2', 'file cannot be read')
# 9476 1 ATL : Assessor scoring complete
# 9476 1 ATL : Score1 scoring complete
# 9476 1 ATL : Scorer2 scoring complete
# 9002 1 VNT_Tutoring : Assessor scoring complete
# 9002 1 VNT_Tutoring : Score1 scoring complete
# 9002 1 VNT_Tutoring : Scorer2 scoring complete
# 9430 1 WIAT_III : Assessor scoring complete
# 9430 1 WIAT_III : Score1 scoring complete
# 9430 1 WIAT_III : Scorer2 scoring complete
# 9002 1 WISC_V : Assessor scoring complete
# 9002 1 WISC_V : Score1 scoring complete
# 9002 1 WISC_V : Scorer2 scoring complete
# 9440 1 ATL : Assessor scoring complete
# 9440 1 ATL : Score1 scoring complete
# 9440 1 ATL : Scorer2 scoring complete
# 9337 1 SPT_CBO : Assessor scoring complete
# 9337 1 SPT_CBO : Scorer2 scoring complete
# 9054 post ATM : Assessor scoring complete
# 9054 post ATM : Score1 scoring complete
# 9054 post ATM : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_Pre_Strategy_Assessment_9040_1', 'file cannot be read')
#
# ('error in cell values for:', 'MET_DKEFS_9496_1', 'file cannot be read')
# 9002 1 WASI_II : Assessor scoring complete
# 9002 1 WASI_II : Score1 scoring complete
# 9002 1 WASI_II : Scorer2 scoring complete
# 9370 1 Geary's : Assessor scoring complete
# 9370 1 Geary's : Score1 scoring complete
# 9145 1 SPT_CBO : Assessor scoring complete
# 9145 1 SPT_CBO : Score1 scoring complete
# 9145 1 SPT_CBO : Scorer2 scoring complete
# 9370 1 WISC_V : Assessor scoring complete
# 9370 1 WISC_V : Score1 scoring complete
# 9297 2 MARS(SEMA) : Assessor scoring complete
# 9297 2 MARS(SEMA) : Score1 scoring complete
# 9297 2 MARS(SEMA) : Scorer2 scoring complete
# 9120 2 MARS(SEMA) : Assessor scoring complete
# 9120 2 MARS(SEMA) : Score1 scoring complete
# 9120 2 MARS(SEMA) : Scorer2 scoring complete
# 9347 1 ATM : Assessor scoring complete
# 9347 1 ATM : Score1 scoring complete
# 9347 1 ATM : Scorer2 scoring complete
# 9496 1 WIAT_III : Assessor scoring complete
# 9496 1 WIAT_III : Score1 scoring complete
# 9496 1 WIAT_III : Scorer2 scoring complete
# 9033 1 WJ_III : Assessor scoring complete
# 9033 1 WJ_III : Score1 scoring complete
# 9033 1 WJ_III : Scorer2 scoring complete
# 9120 1 Learning_Curve : Assessor scoring complete
# 9120 1 Learning_Curve : Score1 scoring complete
# 9120 1 Learning_Curve : Scorer2 scoring complete
# 9370 1 WASI_II : Assessor scoring complete
# 9370 1 WASI_II : Score1 scoring complete
# 9370 1 WASI_II : Scorer2 scoring complete
# 9430 1 DKEFS : Assessor scoring complete
# 9430 1 DKEFS : Score1 scoring complete
# 9430 1 DKEFS : Scorer2 scoring complete
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9347_2', 'file cannot be read')
# 9033 3 Geary's : Assessor scoring complete
# 9033 3 Geary's : Score1 scoring complete
#
# ('error in cell values for:', 'MET_Handedness_9212_1', 'file cannot be read')
# 9040 2 Geary's : Assessor scoring complete
# 9040 2 Geary's : Score1 scoring complete
# 9040 2 Geary's : Scorer2 scoring complete
# 9033 2 ATL : Assessor scoring complete
# 9033 2 ATL : Score1 scoring complete
# 9033 2 ATL : Scorer2 scoring complete
# 9337 1 WISC_V : Assessor scoring complete
# 9337 1 WISC_V : Score1 scoring complete
# 9337 1 WISC_V : Scorer2 scoring complete
# 9054 1 WIAT_III : Assessor scoring complete
# 9054 1 WIAT_III : Score1 scoring complete
# 9054 1 WIAT_III : Scorer2 scoring complete
# 9496 1 MARS(SEMA) : Assessor scoring complete
# 9496 1 MARS(SEMA) : Score1 scoring complete
# 9496 1 MARS(SEMA) : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_neuropsych_CBO_120_1', 'file cannot be read')
# 9430 1 SPT_Tutoring : Assessor scoring complete
# 9430 1 SPT_Tutoring : Score1 scoring complete
# 9430 1 SPT_Tutoring : Scorer2 scoring complete
# 9337 1 WASI_II : Assessor scoring complete
# 9337 1 WASI_II : Score1 scoring complete
# 9337 1 WASI_II : Scorer2 scoring complete
# 9440 1 WASI_II : Assessor scoring complete
# 9440 1 WASI_II : Score1 scoring complete
# 9440 1 WASI_II : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_CBO_scoring_9496', 'file cannot be read')
#
# ('error in cell values for:', 'strategy_assess_9347_Time_3_Y_09_32_39_Ver', 'file cannot be read')
# 9440 1 WISC_V : Assessor scoring complete
# 9440 1 WISC_V : Score1 scoring complete
# 9440 1 WISC_V : Scorer2 scoring complete
#
# ('error in cell values for:', 'WIAT_III_scoring_for_DB_9218', 'file cannot be read')
# 9040 1 WJ_III : Assessor scoring complete
# 9040 1 WJ_III : Score1 scoring complete
# 9040 1 WJ_III : Scorer2 scoring complete
# 9002 1 ATL : Assessor scoring complete
# 9002 1 ATL : Score1 scoring complete
# 9002 1 ATL : Scorer2 scoring complete
# 9496 2 Subtraction : Assessor scoring complete
# 9496 2 Subtraction : Score1 scoring complete
# 9496 2 Subtraction : Scorer2 scoring complete
# 9033 3 ATL : Assessor scoring complete
# 9033 3 ATL : Score1 scoring complete
# 9033 3 ATL : Scorer2 scoring complete
# 9033 2 Geary's : Assessor scoring complete
# 9033 2 Geary's : Score1 scoring complete
# 9033 2 Geary's : Scorer2 scoring complete
# 9040 2 ATL : Assessor scoring complete
# 9040 2 ATL : Score1 scoring complete
# 9040 2 ATL : Scorer2 scoring complete
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9430_2', 'file cannot be read')
# 9002 2 WJ_III : Assessor scoring complete
# 9002 2 WJ_III : Score1 scoring complete
# 9002 2 WJ_III : Scorer2 scoring complete
# 9476 1 WISC_V : Assessor scoring complete
# 9476 1 WISC_V : Score1 scoring complete
# 9476 1 WISC_V : Scorer2 scoring complete
# 9347 1 DKEFS : Score1 scoring complete
# 9347 1 DKEFS : Scorer2 scoring complete
# 9297 1 Subtraction : Assessor scoring complete
# 9297 1 Subtraction : Score1 scoring complete
# 9297 1 Subtraction : Scorer2 scoring complete
# 9120 1 Subtraction : Assessor scoring complete
# 9120 1 Subtraction : Score1 scoring complete
# 9120 1 Subtraction : Scorer2 scoring complete
# 9476 1 WASI_II : Assessor scoring complete
# 9476 1 WASI_II : Score1 scoring complete
# 9476 1 WASI_II : Scorer2 scoring complete
# 9430 1 ATM : Assessor scoring complete
# 9430 1 ATM : Score1 scoring complete
# 9430 1 ATM : Scorer2 scoring complete
# 9297 3 MARS(SEMA) : Assessor scoring complete
# 9297 3 MARS(SEMA) : Score1 scoring complete
# 9297 3 MARS(SEMA) : Scorer2 scoring complete
# 9054 2 Subtraction : Assessor scoring complete
# 9054 2 Subtraction : Score1 scoring complete
# 9054 2 Subtraction : Scorer2 scoring complete
#
# ('error in cell values for:', 'MET_CBO_scoring_9347_1', 'file cannot be read')
#
# ('error in cell values for:', 'MET_Followup_Strategy_Assessment_9297_3', 'file cannot be read')
#
# ('error in cell values for:', 'WASI_scoring_for_DB_All_Grades_9354', 'file cannot be read')
#
# ('error in cell values for:', "Geary's_MET_9054_1", 'file cannot be read')
#
# ('error in cell values for:', 'WASI_II_scoring_for_DB_9839_1', 'file cannot be read')
#
# ('error in cell values for:', 'WASI_scoring_for_DB_All_Grades_19Nov15_9174_1', 'file cannot be read')
#
# ('error in cell values for:', 'Handedness_scoring_9032_1', 'file cannot be read')
# 9496 1 ATM : Assessor scoring complete
# 9496 1 ATM : Score1 scoring complete
# 9496 1 ATM : Scorer2 scoring complete
# 9347 1 WIAT_III : Assessor scoring complete
# 9347 1 WIAT_III : Score1 scoring complete
# 9347 1 WIAT_III : Scorer2 scoring complete
# 9337 1 ATL : Assessor scoring complete
# 9337 1 ATL : Score1 scoring complete
# 9337 1 ATL : Scorer2 scoring complete
# 9476 1 Geary's : Assessor scoring complete
# 9476 1 Geary's : Score1 scoring complete
# 9476 1 Geary's : Scorer2 scoring complete
# 9054 post ATL : Assessor scoring complete
# 9054 post ATL : Score1 scoring complete
# 9054 post ATL : Scorer2 scoring complete
# 9337 2 WJ_III : Assessor scoring complete
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9297_1', 'file cannot be read')
#
# ('error in cell values for:', 'FINAL_IMPORT_MET_Strategy_Assessment_9120_1', 'file cannot be read')
#
# ('error in cell values for:', 'strategy_assess_9033_Time_6_X_14_29_15_Ver', 'file cannot be read')
# 9440 1 Geary's : Assessor scoring complete
# 9440 1 Geary's : Score1 scoring complete
# 9440 1 Geary's : Scorer2 scoring complete
# 9212 1 WIAT_III : Assessor scoring complete
# 9212 1 WIAT_III : Score1 scoring complete
# 9212 1 WIAT_III : Scorer2 scoring complete
# 9347 3 Subtraction : Assessor scoring complete
# 9347 3 Subtraction : Score1 scoring complete
# 9347 3 Subtraction : Scorer2 scoring complete
# 9430 2 Subtraction : Assessor scoring complete
# 9430 2 Subtraction : Score1 scoring complete
# 9430 2 Subtraction : Scorer2 scoring complete
# 9120 2 ATM : Assessor scoring complete
# 9120 2 ATM : Score1 scoring complete
# 9120 2 ATM : Scorer2 scoring complete
# 9297 2 ATM : Assessor scoring complete
# 9297 2 ATM : Score1 scoring complete
# 9297 2 ATM : Scorer2 scoring complete
# 9370 1 ATL : Assessor scoring complete
# 9370 1 ATL : Score1 scoring complete
# 9370 1 ATL : Scorer2 scoring complete
# 9071 1 WASI_II : Assessor scoring complete
# 9071 1 WASI_II : Score1 scoring complete
# 9071 1 WASI_II : Scorer2 scoring complete

# %% [markdown]
# ## Assessor scoring needed:

# %%
for subj_data_file in os.listdir(all_assess_dirs):
    print subj_data_file
    subj_df=pd.read_excel(subj_data_file,sheetname='Import_Formula',header=[0],skiprows=None,dtype=str)
#     subj_df.to_csv('test'+file_prefix+'.csv')
    try:
#         subj_df=pd.read_excel(subj_data_file,sheetname='Import_Formula',header=[0],skiprows=None,dtype=str)
        print subj_data_file
    except:
        continue
#         subj_df.fillna(value="",axis=0,inplace=True)
#         subj=subj_data_file.split('_')[2]
#         visit=subj_data_file.split('.')[0].split('_')[3]
# #         subj_df.to_excel(file_prefix+'_import.xlsx',index=False,sheet_name='Import')
#     except:
#         print "**error for {}".format(file_prefix)
#         continue

# %%
[assess for assess in sorted(needs_assessor)]
# Out:
# [['9002', '1', 'DKEFS'],
#  ['9002', '2', "Geary's"],
#  ['9002', '2', 'Subtraction'],
#  ['9297', '1', 'SPT_CBO'],
#  ['9347', '1', 'DKEFS'],
#  ['9347', '1', 'VNT_CBO'],
#  ['9347', '1', 'WISC_V'],
#  ['9370', '1', 'VNT_CBO'],
#  ['9370', '1', 'VNT_Tutoring'],
#  ['9476', '1', 'DKEFS']]

# %% [markdown]
# ## Score 1 Needed

# %%
[score1 for score1 in sorted(needs_score1)]
# Out:
# [['9002', '2', "Geary's"],
#  ['9002', '2', 'Subtraction'],
#  ['9297', '1', 'SPT_CBO'],
#  ['9337', '1', 'SPT_CBO'],
#  ['9337', '1', 'SPT_Tutoring'],
#  ['9337', '2', 'ATL'],
#  ['9337', '2', 'ATM'],
#  ['9337', '2', "Geary's"],
#  ['9337', '2', 'MARS(SEMA)'],
#  ['9337', '2', 'Subtraction'],
#  ['9337', '2', 'WJ_III'],
#  ['9347', '1', 'VNT_CBO'],
#  ['9370', '1', 'VNT_CBO'],
#  ['9370', '1', 'VNT_Tutoring'],
#  ['9430', '1', 'WJ_III']]

# %% [markdown]
# ## Score 2 Needed

# %%
[score2 for score2 in sorted(needs_score2)]
# Out:
# [['9002', '2', "Geary's"],
#  ['9002', '2', 'Subtraction'],
#  ['9033', '3', "Geary's"],
#  ['9054', '1', 'LearningCurve'],
#  ['9054', '1', 'WISC_V'],
#  ['9337', '1', 'Learning_Curve'],
#  ['9337', '1', 'SPT_Tutoring'],
#  ['9337', '2', "Geary's"],
#  ['9337', '2', 'Subtraction'],
#  ['9337', '2', 'WJ_III'],
#  ['9347', '1', 'VNT_Tutoring'],
#  ['9370', '1', "Geary's"],
#  ['9370', '1', 'Learning_Curve'],
#  ['9370', '1', 'VNT_Tutoring'],
#  ['9370', '1', 'WISC_V'],
#  ['9430', '1', 'WJ_III']]

# %%
for subj_data_file in os.listdir(all_assess_dirs):
    print subj_data_file
    try:
        subj_df=pd.read_excel(subj_data_file,sheetname='Import_Formula',header=[0],skiprows=None,dtype=str)
        subj_df.fillna(value="",axis=0,inplace=True)
        subj=subj_data_file.split('_')[2]
        visit=subj_data_file.split('.')[0].split('_')[3]
        file_prefix=subj_data_file.split('.')[0]
#         subj_df.to_excel(file_prefix+'_import.xlsx',index=False,sheet_name='Import')
    except:
        print "error for %s" % file_prefix
        continue
# Out:
# MET_WJ_III_9370_1.xlsx
# MET_ATM_9496_2.xlsx
# MET_ATL_9337_2.xlsx
# MET_WISC_V_9033_1.xlsx
# MET_Geary's_9476_2.xlsx
# MET_WJ_III_9337_1.xlsx
# MET_Handedness_9120_1.xlsx
# error for MET_WJ_III_9337_1
# FINAL_IMPORT_MET_Strategy_Assessment_9120_2.xlsx
# error for MET_WJ_III_9337_1
# MET_ATM_9032_1.xlsx
# FINAL_IMPORT_MET_Strategy_Assessment_9297_2.xlsx
# error for MET_ATM_9032_1
# MET_Geary's_9440_2.xlsx
# MET_Learning_Curve_9476.xlsx
# MET_ATM_9297_1.xlsx
# MET_ATM_9120_1.xlsx
# MET_MARS(SEMA)_9347_2.xlsx
# strategy_assess_9033_Time_2_X_10_29_42_Ver.xlsx
# MET_MARS(SEMA)_9297_3.xlsx
# MET_Subtraction_9054_2.xlsx
# MET_CBO_scoring_9347_1.xlsx
# error for MET_Subtraction_9054_2
# MET_Followup_Strategy_Assessment_9297_3.xlsx
# error for MET_Subtraction_9054_2
# WASI_scoring_for_DB_All_Grades_9354.xlsx
# error for MET_Subtraction_9054_2
# Geary's_MET_9054_1.xlsx
# WASI_II_scoring_for_DB_9839_1.xlsx
# error for Geary's_MET_9054_1
# WASI_scoring_for_DB_All_Grades_19Nov15_9174_1.xlsx
# error for Geary's_MET_9054_1
# Handedness_scoring_9032_1.xlsx
# error for Geary's_MET_9054_1
# MET_ATM_9496_1.xlsx
# MET_WIAT_III_9347_1.xlsx
# MET_ATL_9337_1.xlsx
# MET_Geary's_9476_1.xlsx
# MET_ATL_9054_post.xlsx
# MET_WJ_III_9337_2.xlsx
# FINAL_IMPORT_MET_Strategy_Assessment_9297_1.xlsx
# error for MET_WJ_III_9337_2
# FINAL_IMPORT_MET_Strategy_Assessment_9120_1.xlsx
# error for MET_WJ_III_9337_2
# strategy_assess_9033_Time_6_X_14_29_15_Ver.xlsx
# error for MET_WJ_III_9337_2
# MET_Geary's_9440_1.xlsx
# MET_WIAT_III_9212_1.xlsx
# MET_Subtraction_9347_3.xlsx
# MET_Subtraction_9430_2.xlsx
# MET_ATM_9120_2.xlsx
# MET_ATM_9297_2.xlsx
# MET_ATL_9370_1.xlsx
# MET_WASI_II_9071_1.xlsx

# %% [markdown]
# ## "Check" found, followup on subjects below

# %%
[to_check for to_check in sorted(needs_check)]
# Out:
# [['9002', '2', "Geary's"],
#  ['9002', '2', 'Subtraction'],
#  ['9033', '1', 'Learning_Curve'],
#  ['9040', '1', 'SPT_CBO'],
#  ['9054', '1', 'LearningCurve'],
#  ['9120', '1', 'MARS(SEMA)'],
#  ['9297', '1', 'SPT_CBO'],
#  ['9337', '1', 'Learning_Curve'],
#  ['9337', '1', 'SPT_CBO'],
#  ['9337', '1', 'SPT_Tutoring'],
#  ['9337', '2', 'ATL'],
#  ['9337', '2', 'ATM'],
#  ['9337', '2', "Geary's"],
#  ['9337', '2', 'MARS(SEMA)'],
#  ['9337', '2', 'Subtraction'],
#  ['9347', '1', 'VNT_CBO'],
#  ['9370', '1', 'ATM'],
#  ['9370', '1', 'Learning_Curve'],
#  ['9370', '1', 'VNT_CBO'],
#  ['9430', '1', 'SPT_CBO']]

# %% [markdown]
# ## How to compare NP drive data with data on box

# %% [markdown]
# ### *** Requires you to have a local copy of the NP computer and a copy of the data that is of inerest
#
# aka,
# 1. Make a folder on your computer and copy the relevant NP subjects
# 2. Make a new folder in your PHI safe box folder
# 3. Copy the relevant subjects from the neuropsych data folder on box into the folder you created in step 2

# %%
`cd ~/scratch/Neuropsych_organized/NeuroPsych/;` #change directory to your LOCAL COPY 

for x in `ls -d 9*[0-9]*`; do 
    echo $x; 
    #rclone check ~/scratch/Neuropsych_organized/NeuroPsych/`echo $x` stanford_box:/SCSNL\ Neuropsych\ data/behavioral_data/`echo ${x}`;
done
